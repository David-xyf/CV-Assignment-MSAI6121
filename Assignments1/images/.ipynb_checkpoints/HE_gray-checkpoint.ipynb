# %%
from PIL import Image
import os
# %matplotlib inline

# %%
images = os.listdir("images_gray/")

# %%
images
# Out:
# ['gray_sample01.jpg',
#  'gray_sample02.jpg',
#  'gray_sample03.jpg',
#  'gray_sample04.jpg',
#  'gray_sample05.jpg',
#  'gray_sample06.jpg',
#  'gray_sample07.jpg',
#  'gray_sample08.jpg']

# %%
IMAGES_PATH = 'images_gray\\'
IMAGE_SIZE = 256
IMAGE_ROW = 2
IMAGE_COLUMN = 4
IMAGES_SAVE_PATH = 'composed_images_gray.jpg'

# get all iamges' names from the current dir
image_names = [name for name in os.listdir(IMAGES_PATH)]
# 简单的对于参数的设定和实际图片集的大小进行数量判断
if len(image_names) != IMAGE_ROW * IMAGE_COLUMN:
    raise ValueError("合成图片的参数和要求的数量不能匹配！")


def images_compose():
    # define the function of images' compositions
    to_image = Image.new(
        'RGB', (IMAGE_COLUMN * IMAGE_SIZE, IMAGE_ROW * IMAGE_SIZE))  # 创建一个新图
    for y in range(1, IMAGE_ROW + 1):
        for x in range(1, IMAGE_COLUMN + 1):
            from_image = Image.open(IMAGES_PATH +
                                    image_names[IMAGE_COLUMN *
                                                (y - 1) + x - 1]).resize(
                                                    (IMAGE_SIZE, IMAGE_SIZE),
                                                    Image.ANTIALIAS)
            to_image.paste(from_image,
                           ((x - 1) * IMAGE_SIZE, (y - 1) * IMAGE_SIZE))

    to_image.save(IMAGES_SAVE_PATH)
    return to_image


images_compose()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x24AF86D4548>

# %%
# histogram equalization algorithm for basic pictures
def histEqAlgo(imgArr):
    hist, bins = np.histogram(imgArr, 255)
    cdf = np.cumsum(hist)
    cdf = 255 * (cdf / cdf[-1])  # mapping
    res = np.interp(imgArr.flatten(), bins[:-1], cdf)
    res = res.reshape(imgArr.shape)
    return Image.fromarray(res)

# %%
for i in range(1,9):
    plt.subplot(2,4,i)
    plt.axis("off")
    img = Image.open("images_gray/gray_sample0"+str(i)+".jpg")
    gray_arr = np.array(img.convert('L'))
    image= histEqAlgo(gray_arr)
    plt.imshow(image)
    image=image.convert('RGB')
    image.save("images_gray/gray_res"+str(i)+".jpg")

# %%
IMAGES_PATH = 'images_gray\\'
IMAGE_SIZE = 256
IMAGE_ROW = 4
IMAGE_COLUMN = 4
IMAGES_SAVE_PATH = 'composed_images_gray_res.jpg'

# get all iamges' names from the current dir
image_names = [name for name in os.listdir(IMAGES_PATH) ]
# 简单的对于参数的设定和实际图片集的大小进行数量判断
if len(image_names) != IMAGE_ROW * IMAGE_COLUMN:
    raise ValueError("合成图片的参数和要求的数量不能匹配！")


def images_compose():
    # define the function of images' compositions
    to_image = Image.new(
        'RGB', (IMAGE_COLUMN * IMAGE_SIZE, IMAGE_ROW * IMAGE_SIZE))  # 创建一个新图
    for y in range(1, IMAGE_ROW + 1):
        for x in range(1, IMAGE_COLUMN + 1):
            from_image = Image.open(IMAGES_PATH +
                                    image_names[IMAGE_COLUMN *
                                                (y - 1) + x - 1]).resize(
                                                    (IMAGE_SIZE, IMAGE_SIZE),
                                                    Image.ANTIALIAS)
            to_image.paste(from_image,
                           ((x - 1) * IMAGE_SIZE, (y - 1) * IMAGE_SIZE))

    to_image.save(IMAGES_SAVE_PATH)
    return to_image


images_compose()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x24A904AD6C8>
